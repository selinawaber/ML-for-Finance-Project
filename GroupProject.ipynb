# %% [markdown]
# # Project ML in Finance Group 5
# ### April 2023
#
#
# #### Cyrill Stoll, Arthur Schlegel, Aleksandar Kuljanin and Selina Waber

# %% [markdown]
# ## Introduction
#
# Dean De Cock created the Ames Housing dataset here the link to the [Dataset](https://www.openml.org/search?type=data&sort=runs&id=42165&status=active). This dataset provides information about the sales of residential properties in Ames, Iowa between 2006 and 2010. It consists of 1460 observations and includes 80 explanatory variables that are used to evaluate the values of homes, the variable 'Class'.

# %% [markdown]
# ## Importing Librarys

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.rcParams['font.size'] = 10

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# packages for decision tree / Random forest
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler 
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import RandomOverSampler

# additional packages used for logreg
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.exceptions import ConvergenceWarning
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA

# additional packages used for SVM
from sklearn import svm
from sklearn.svm import SVC
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import RandomOverSampler
# Out:
# /var/folders/6t/90p2j4ms0vx87ql4wxn5_pn80000gn/T/ipykernel_24859/1663057256.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Function for Printing and Showing Confusion Matrix

# %%
def print_results_crossvalidation(func, X_test, y_test):
  
  std_best_score = func.cv_results_["std_test_score"][func.best_index_]
  print(f"Best parameters: {func.best_params_}")
  print(f"Mean CV score: {func.best_score_:}")
  print(f"Standard deviation of CV score: {std_best_score:}")
  print("Test Score:".format(func.score(X_test, y_test)))

def report(y_true, y_pred):
    
  class_report = metrics.classification_report(y_true, y_pred)
  print(class_report)
  conf_matrix = confusion_matrix(y_true, y_pred, normalize = "true")
  conf_matrix = pd.DataFrame(conf_matrix, ["Class 0", "Class 1", " Class 2", "Class 3", " Class 4"],  ["Class 0", "Class 1", " Class 2", "Class 3", " Class 4"])
  sns.heatmap(conf_matrix, annot = True).set(xlabel = "Assigned Class", ylabel = "True Class", title = "Confusion Matrix")

# %% [markdown]
# ## Load Data

# %%
# Load data
df = pd.read_csv("GroupProjectDataSet.csv", sep=',', index_col='Id')
print('Shape of data frame:', df.shape)
df.head()
# Out:
# Shape of data frame: (1460, 80)
#        MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# Id
# 530.0        20.0       RL          NaN  32668.0   Pave   NaN      IR1  \
# 492.0        50.0       RL         79.0   9490.0   Pave   NaN      Reg
# 460.0        50.0       RL          NaN   7015.0   Pave   NaN      IR1
# 280.0        60.0       RL         83.0  10005.0   Pave   NaN      Reg
# 656.0       160.0       RM         21.0   1680.0   Pave   NaN      Reg
#
#       LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature
# Id                                     ...
# 530.0         Lvl    AllPub   CulDSac  ...      0.0    NaN    NaN         NaN  \
# 492.0         Lvl    AllPub    Inside  ...      0.0    NaN  MnPrv         NaN
# 460.0         Bnk    AllPub    Corner  ...      0.0    NaN    NaN         NaN
# 280.0         Lvl    AllPub    Inside  ...      0.0    NaN    NaN         NaN
# 656.0         Lvl    AllPub    Inside  ...      0.0    NaN    NaN         NaN
#
#       MiscVal MoSold  YrSold  SaleType  SaleCondition  Class
# Id
# 530.0     0.0    3.0  2007.0        WD         Alloca    2.0
# 492.0     0.0    8.0  2006.0        WD         Normal    1.0
# 460.0     0.0    7.0  2009.0        WD         Normal    1.0
# 280.0     0.0    3.0  2008.0        WD         Normal    1.0
# 656.0     0.0    3.0  2010.0        WD         Family    0.0
#
# [5 rows x 80 columns]

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000  \
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...  \
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000  \
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold        Class
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753     1.306164
# std      40.177307    496.123024     2.703626     1.328095     0.784595
# min       0.000000      0.000000     1.000000  2006.000000     0.000000
# 25%       0.000000      0.000000     5.000000  2007.000000     1.000000
# 50%       0.000000      0.000000     6.000000  2008.000000     1.000000
# 75%       0.000000      0.000000     8.000000  2009.000000     2.000000
# max     738.000000  15500.000000    12.000000  2010.000000     4.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Overview
#
# The data set consists of 1460 observations with 81 variables (including the target variable "(prize) class" and the id variable). 79 variables are descriptive variables that should explain Class.
#
# Quantitative: 1stFlrSF, 2ndFlrSF, 3SsnPorch, BedroomAbvGr, BsmtFinSF1, BsmtFinSF2, BsmtFullBath, BsmtHalfBath, BsmtUnfSF, EnclosedPorch, Fireplaces, FullBath, GarageArea, GarageCars, GarageYrBlt, GrLivArea, HalfBath, KitchenAbvGr, LotArea, LotFrontage, LowQualFinSF, MSSubClass, MasVnrArea, MiscVal, MoSold, OpenPorchSF, OverallCond, OverallQual, PoolArea, ScreenPorch, TotRmsAbvGrd, TotalBsmtSF, WoodDeckSF, YearBuilt, YearRemodAdd, YrSold
#
# Qualitative: Alley, BldgType, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, BsmtQual, CentralAir, Condition1, Condition2, Electrical, ExterCond, ExterQual, Exterior1st, Exterior2nd, Fence, FireplaceQu, Foundation, Functional, GarageCond, GarageFinish, GarageQual, GarageType, Heating, HeatingQC, HouseStyle, KitchenQual, LandContour, LandSlope, LotConfig, LotShape, MSZoning, MasVnrType, MiscFeature, Neighborhood, PavedDrive, PoolQC, RoofMatl, RoofStyle, SaleCondition, SaleType, Street, Utilities

# %%
numCols = list(df.select_dtypes(exclude='object').columns)
print(f"There are {len(numCols)} numerical features:\n", numCols)
# Out:
# There are 37 numerical features:
#  ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'Class']

# %%
catCols = list(df.select_dtypes(include='object').columns)
print(f"There are {len(catCols)} categorical features:\n", catCols)
# Out:
# There are 43 categorical features:
#  ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ## Handling Missing Values
#
# Identifying missing values in data is crucial before determining the appropriate course of action, such as dropping features or imputing missing values, as many machine learning algorithms generate errors when trained on incomplete data.

# %%
# Plot missing values
missing = df.isnull().sum().sort_values(ascending=False)
missing = missing[missing > 0]
missing.plot.bar()
# Out:
# <Axes: >

# %%
# Assess missing values
cols = df.columns[df.isna().any()]
df_nan = df[cols].copy()
df_nan['Class'] = df['Class']


# Plot missing values 2.0
plt.figure(figsize=(10, 6))
sns.heatmap(df_nan.isna().transpose(),
            cmap="Blues",
            cbar_kws={'label': 'Missing Values'});

# %%
# Percentage of missing values for the variables
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([missing, percent], axis=1, keys=['Nr. of missing values', 'Share'])
missing_data.head(22)
# Out:
#               Nr. of missing values     Share
# PoolQC                       1453.0  0.995205
# MiscFeature                  1406.0  0.963014
# Alley                        1369.0  0.937671
# Fence                        1179.0  0.807534
# MasVnrType                    872.0  0.597260
# FireplaceQu                   690.0  0.472603
# LotFrontage                   259.0  0.177397
# GarageYrBlt                    81.0  0.055479
# GarageCond                     81.0  0.055479
# GarageType                     81.0  0.055479
# GarageFinish                   81.0  0.055479
# GarageQual                     81.0  0.055479
# BsmtExposure                   38.0  0.026027
# BsmtFinType2                   38.0  0.026027
# BsmtCond                       37.0  0.025342
# BsmtQual                       37.0  0.025342
# BsmtFinType1                   37.0  0.025342
# MasVnrArea                      8.0  0.005479
# Electrical                      1.0  0.000685
# MSSubClass                      NaN  0.000000
# Fireplaces                      NaN  0.000000
# Functional                      NaN  0.000000

# %% [markdown]
# ### Filling missing values for variables where appropriate
#
# 19 variables have missing values. Of the 19 variables four (PoolQC, MiscFeature, Alley, Fence) have more than 50% missing data and one (FireplaceQu) with nearly 50% missing data. But often NA does not mean that there is no data available. Instead (especially for thecategorical variables) it means that the house is lacking this specific object. NA in the PoolQC variable means that there is no pool; NA in the Alley variable means that there is "no alley access". All the descriptions of which NA stand for non-available data and which stand for a missing trait can be found in the data description.

# %% [markdown]
# #### Filling Categorical Variables
#
# The following variables have NAs that can be filled:
#
# - PoolQC: Na = No Pool
# - MiscFeature: Na = None
# - Alley: NA = No alley access
# - Fence: NA = No Fence
# - FireplaceQu: NA = No Fireplace
# - GarageCond: NA = No Garage
# - GarageType: NA = No Garage
# - GarageFinish: NA = No Garage
# - GarageQual: NA = No Garage
# - BsmtFinType2: NA = No Basement
# - BsmtExposure: NA = No Basement
# - BsmtQual: NA = No Basement
# - BsmtCond: NA = No Basement
# - BsmtFinType1: NA = No Basement
# - MasVnrType: NA = None

# %%
## Filling Categorical Variables 

df["PoolQC"] = df["PoolQC"].fillna(value = "No")
df["MiscFeature"] = df["MiscFeature"].fillna(value = "No")
df["Alley"] = df["Alley"].fillna(value = "No")
df["Fence"] = df["Fence"].fillna(value = "No")
df["FireplaceQu"] = df["FireplaceQu"].fillna(value = "No")
df["GarageCond"] = df["GarageCond"].fillna(value = "No")
df["GarageType"] = df["GarageType"].fillna(value = "No")
df["GarageFinish"] = df["GarageFinish"].fillna(value = "No")
df["GarageQual"] = df["GarageQual"].fillna(value = "No")
df["BsmtFinType2"] = df["BsmtFinType2"].fillna(value = "No")
df["BsmtExposure"] = df["BsmtExposure"].fillna(value = "No")
df["BsmtQual"] = df["BsmtQual"].fillna(value = "No")
df["BsmtCond"] = df["BsmtCond"].fillna(value = "No")
df["BsmtFinType1"] = df["BsmtFinType1"].fillna(value = "No")
df["MasVnrType"] = df["MasVnrType"].fillna(value= "No") #newly added

# %% [markdown]
# For all but five variables we coud fill the missing data because with them NA indicates the lack of the corresponding trait. For LotFrontage we miss 17% of the values and 5.5% for GarageYrBlt.

# %% [markdown]
# #### Filling missing values for numerical data

# %%
## Numerical Variables
missing_numerical = ['GarageArea', 'GarageCars', 'BsmtFinSF1',
                     'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF',
                     'BsmtFullBath', 'BsmtHalfBath', 'MasVnrArea']

df[missing_numerical] = df[missing_numerical].fillna(0)

# %% [markdown]
# #### Filling special variables

# %%
# Filling special variables

df["GarageYrBlt"] = df["GarageYrBlt"].fillna(df["YearBuilt"]) 
# assuming that the garge was bulit with the house 


df["LotFrontage"] = df["LotFrontage"].fillna(df["LotFrontage"].mean())



most_frequent= df['Electrical'].value_counts().idxmax()
df["Electrical"] = df["Electrical"].fillna(most_frequent)

# %% [markdown]
# ## Create New Variables

# %%
df['totalSqFeet'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']
df['totalBathroom'] = df["FullBath"] + df["BsmtFullBath"] + 0.5 * (df["HalfBath"] + df["BsmtHalfBath"])
df['houseAge'] = df["YrSold"] - df["YearBuilt"]
df['reModeled'] = np.where(df["YearRemodAdd"] == df["YearBuilt"], 0, 1)
df['isNew'] = np.where(df["YrSold"] == df["YearBuilt"], 1, 0)

# %% [markdown]
# Dropping columns

# %%
not_used_anymore = ['TotalBsmtSF','1stFlrSF', '2ndFlrSF',
                    "FullBath", "BsmtFullBath", "HalfBath",
                    "BsmtHalfBath", "YearBuilt", "YearRemodAdd"  ]

df= df.drop(not_used_anymore, axis=1)

# %%
df.columns.values
# Out:
# array(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'LowQualFinSF',
#        'GrLivArea', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature',
#        'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition',
#        'Class', 'totalSqFeet', 'totalBathroom', 'houseAge', 'reModeled',
#        'isNew'], dtype=object)

# %% [markdown]
# ## Feature Engineering
#
#
# ### Dealing with Categorical Features (Encoding Categorical Variables)

# %%
# Numerical variables that should be handled as categorical variables
df = df.replace({"MSSubClass" : {20 : "SC20", 30 : "SC30", 40 : "SC40", 45 : "SC45", 
50 : "SC50", 60 : "SC60", 70 : "SC70", 75 : "SC75", 
80 : "SC80", 85 : "SC85", 90 : "SC90", 120 : "SC120", 
150 : "SC150", 160 : "SC160", 180 : "SC180", 190 : "SC190"}})

df = df.replace({"MoSold" : {1 : "Jan", 2 : "Feb", 3 : "Mar", 4 : "Apr", 5 : "May", 6 : "Jun",
7 : "Jul", 8 : "Aug", 9 : "Sep", 10 : "Oct", 11 : "Nov", 12 : "Dec"}})

# %%
# other approach:
#to_factor_cols = ['YrSold', 'MoSold', 'MSSubClass']
#for col in to_factor_cols:
#    X[col] = X[col].apply(str)

# %% [markdown]
# ## Numerical Features

# %% [markdown]
# #### Histograms

# %%
#  Visualize data to gain insights (Histograms)
df.hist(figsize=(30, 20), bins = 15, edgecolor = 'black', grid = False, color = 'royalblue')
plt.suptitle('Histograms of numerical features', x = 0.5, y = 1.02, size = 35)
# Out:
# Text(0.5, 1.02, 'Histograms of numerical features')

# %% [markdown]
# #### Top 10 numerical variables highly correlated with `Class`:

# %%
#corr_mat = df.corr(numeric_only=False).Class.sort_values(ascending=False)
#corr_mat.head(11)

# %% [markdown]
# #### Recursive Feature Elimination
#
# What are the top 10 features selected by Recursive Feature Elimination?

# %%
# Asign columns to feature matrix X interim and response vector y interim
X_interim = df.loc[:, df.columns != "Class"]
y = df["Class"]

from sklearn.model_selection import train_test_split
X_train_interim , X_test_interim, y_train_interim, y_test_interim = train_test_split(X_interim, y, 
                                                    test_size=0.3, 
                                                    random_state=0, 
                                                    stratify=y)

frames = [X_train_interim, y_train_interim]
df_train_interim = pd.concat(frames, axis=1)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

estimator = LinearRegression()
rfe = RFE(estimator, n_features_to_select=10, step=1)
selector = rfe.fit(X_train_interim.fillna(0).select_dtypes(exclude='object'), y_train_interim)
selectedFeatures = list(
    X_interim.select_dtypes(exclude='object').columns[selector.support_])
selectedFeatures
# Out:
# ['OverallQual',
#  'OverallCond',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'totalBathroom',
#  'reModeled',
#  'isNew']

# %% [markdown]
# ### Overall Quality
#
# Overall quality is a very important feature e.g. higher quality houses are more expensive.

# %%
sns.boxplot(x='OverallQual', y='Class', data=df)
title = plt.title('House Price/Class by Overall Quality')

# %% [markdown]
# ### Living Area
#
# The price of a house is linearly correlated with its living area. By examining the scatter plot depicted below, it is evident that there exist some outliers in the data, particularly the two houses positioned in the bottom-right corner. These houses have a living area of more than 4000 square feet but are priced lower than Class 2.

# %%
print("Correlation: ", df[['GrLivArea','Class']].corr().iloc[1, 0])
sns.jointplot(x=df['GrLivArea'],y= df['Class'], kind='reg', marginal_kws={'kde': True})
# Out:
# Correlation:  0.6516744793229786

# %% [markdown]
# ### GarageCars
#
# houses with garage that can hold 4 cars are cheaper than houses with 3 garages.

# %%
sns.boxplot(x='GarageCars', y='Class', data=df)
title = plt.title('House Price/Class by Garage Size')

# %% [markdown]
# ### House Age
#
# In addition to living area, the age of a house also influences its price significantly. Typically, newer houses command higher prices on average. However, it is worth noting that there are some houses constructed before 1900 that have a relatively high price despite their age.

# %%
sns.scatterplot(x='houseAge', y='Class', data=df)
title = plt.title('House Price/Class by Year Built')

# %% [markdown]
# ## Asign columns to feature matrix X and response vector y

# %%
# Asign columns to feature matrix X and response vector y

X = df.loc[:, df.columns != "Class"]
y = df["Class"] 

print(X.shape)
print(y.shape)
# Out:
# (1460, 75)
# (1460,)

# %% [markdown]
# ## Adding Dummies

# %%
# factorise the binary variables (no need to create two dummy variables)
# ---> Problem of Multicollinearity 
#Without this the get_dummies would create two variables CentralAir_y and CentralAir_n
X["StreetFac"] = X.Street.factorize()[0]
X["CentralAirFac"] = X.CentralAir.factorize()[0]

# %%
# Factorize categorical values, assign output to X
# create (multiple) dummy variables for a categorical variable
X = pd.get_dummies(X.iloc[:,:]) 

print(X.shape)
X.head()
# Out:
# (1460, 324)
#        LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1
# Id
# 530.0    70.049958  32668.0          6.0          3.0         0.0      1219.0  \
# 492.0    79.000000   9490.0          6.0          7.0         0.0       403.0
# 460.0    70.049958   7015.0          5.0          4.0       161.0       185.0
# 280.0    83.000000  10005.0          7.0          5.0       299.0       392.0
# 656.0    21.000000   1680.0          6.0          5.0       381.0         0.0
#
#        BsmtFinSF2  BsmtUnfSF  LowQualFinSF  GrLivArea  ...  SaleType_ConLw
# Id                                                     ...
# 530.0         0.0      816.0           0.0     2515.0  ...           False  \
# 492.0       165.0      238.0           0.0     1578.0  ...           False
# 460.0         0.0      524.0           0.0     1203.0  ...           False
# 280.0         0.0      768.0           0.0     2022.0  ...           False
# 656.0         0.0      525.0           0.0     1092.0  ...           False
#
#        SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml
# Id
# 530.0         False         False         True                  False  \
# 492.0         False         False         True                  False
# 460.0         False         False         True                  False
# 280.0         False         False         True                  False
# 656.0         False         False         True                  False
#
#        SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family
# Id
# 530.0                  False                  True                 False  \
# 492.0                  False                 False                 False
# 460.0                  False                 False                 False
# 280.0                  False                 False                 False
# 656.0                  False                 False                  True
#
#        SaleCondition_Normal  SaleCondition_Partial
# Id
# 530.0                 False                  False
# 492.0                  True                  False
# 460.0                  True                  False
# 280.0                  True                  False
# 656.0                 False                  False
#
# [5 rows x 324 columns]

# %%
X.columns.values
# Out:
# array(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'LowQualFinSF', 'GrLivArea', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold',
#        'totalSqFeet', 'totalBathroom', 'houseAge', 'reModeled', 'isNew',
#        'StreetFac', 'CentralAirFac', 'MSSubClass_SC120',
#        'MSSubClass_SC160', 'MSSubClass_SC180', 'MSSubClass_SC190',
#        'MSSubClass_SC20', 'MSSubClass_SC30', 'MSSubClass_SC40',
#        'MSSubClass_SC45', 'MSSubClass_SC50', 'MSSubClass_SC60',
#        'MSSubClass_SC70', 'MSSubClass_SC75', 'MSSubClass_SC80',
#        'MSSubClass_SC85', 'MSSubClass_SC90', 'MSZoning_C (all)',
#        'MSZoning_FV', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM',
#        'Street_Grvl', 'Street_Pave', 'Alley_Grvl', 'Alley_No',
#        'Alley_Pave', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3',
#        'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS',
#        'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub',
#        'Utilities_NoSeWa', 'LotConfig_Corner', 'LotConfig_CulDSac',
#        'LotConfig_FR2', 'LotConfig_FR3', 'LotConfig_Inside',
#        'LandSlope_Gtl', 'LandSlope_Mod', 'LandSlope_Sev',
#        'Neighborhood_Blmngtn', 'Neighborhood_Blueste',
#        'Neighborhood_BrDale', 'Neighborhood_BrkSide',
#        'Neighborhood_ClearCr', 'Neighborhood_CollgCr',
#        'Neighborhood_Crawfor', 'Neighborhood_Edwards',
#        'Neighborhood_Gilbert', 'Neighborhood_IDOTRR',
#        'Neighborhood_MeadowV', 'Neighborhood_Mitchel',
#        'Neighborhood_NAmes', 'Neighborhood_NPkVill',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge',
#        'Neighborhood_NridgHt', 'Neighborhood_OldTown',
#        'Neighborhood_SWISU', 'Neighborhood_Sawyer',
#        'Neighborhood_SawyerW', 'Neighborhood_Somerst',
#        'Neighborhood_StoneBr', 'Neighborhood_Timber',
#        'Neighborhood_Veenker', 'Condition1_Artery', 'Condition1_Feedr',
#        'Condition1_Norm', 'Condition1_PosA', 'Condition1_PosN',
#        'Condition1_RRAe', 'Condition1_RRAn', 'Condition1_RRNe',
#        'Condition1_RRNn', 'Condition2_Artery', 'Condition2_Feedr',
#        'Condition2_Norm', 'Condition2_PosA', 'Condition2_PosN',
#        'Condition2_RRAe', 'Condition2_RRAn', 'Condition2_RRNn',
#        'BldgType_1Fam', 'BldgType_2fmCon', 'BldgType_Duplex',
#        'BldgType_Twnhs', 'BldgType_TwnhsE', 'HouseStyle_1.5Fin',
#        'HouseStyle_1.5Unf', 'HouseStyle_1Story', 'HouseStyle_2.5Fin',
#        'HouseStyle_2.5Unf', 'HouseStyle_2Story', 'HouseStyle_SFoyer',
#        'HouseStyle_SLvl', 'RoofStyle_Flat', 'RoofStyle_Gable',
#        'RoofStyle_Gambrel', 'RoofStyle_Hip', 'RoofStyle_Mansard',
#        'RoofStyle_Shed', 'RoofMatl_ClyTile', 'RoofMatl_CompShg',
#        'RoofMatl_Membran', 'RoofMatl_Metal', 'RoofMatl_Roll',
#        'RoofMatl_Tar&Grv', 'RoofMatl_WdShake', 'RoofMatl_WdShngl',
#        'Exterior1st_AsbShng', 'Exterior1st_AsphShn',
#        'Exterior1st_BrkComm', 'Exterior1st_BrkFace', 'Exterior1st_CBlock',
#        'Exterior1st_CemntBd', 'Exterior1st_HdBoard',
#        'Exterior1st_ImStucc', 'Exterior1st_MetalSd',
#        'Exterior1st_Plywood', 'Exterior1st_Stone', 'Exterior1st_Stucco',
#        'Exterior1st_VinylSd', 'Exterior1st_Wd Sdng',
#        'Exterior1st_WdShing', 'Exterior2nd_AsbShng',
#        'Exterior2nd_AsphShn', 'Exterior2nd_Brk Cmn',
#        'Exterior2nd_BrkFace', 'Exterior2nd_CBlock', 'Exterior2nd_CmentBd',
#        'Exterior2nd_HdBoard', 'Exterior2nd_ImStucc',
#        'Exterior2nd_MetalSd', 'Exterior2nd_Other', 'Exterior2nd_Plywood',
#        'Exterior2nd_Stone', 'Exterior2nd_Stucco', 'Exterior2nd_VinylSd',
#        'Exterior2nd_Wd Sdng', 'Exterior2nd_Wd Shng', 'MasVnrType_BrkCmn',
#        'MasVnrType_BrkFace', 'MasVnrType_No', 'MasVnrType_Stone',
#        'ExterQual_Ex', 'ExterQual_Fa', 'ExterQual_Gd', 'ExterQual_TA',
#        'ExterCond_Ex', 'ExterCond_Fa', 'ExterCond_Gd', 'ExterCond_Po',
#        'ExterCond_TA', 'Foundation_BrkTil', 'Foundation_CBlock',
#        'Foundation_PConc', 'Foundation_Slab', 'Foundation_Stone',
#        'Foundation_Wood', 'BsmtQual_Ex', 'BsmtQual_Fa', 'BsmtQual_Gd',
#        'BsmtQual_No', 'BsmtQual_TA', 'BsmtCond_Fa', 'BsmtCond_Gd',
#        'BsmtCond_No', 'BsmtCond_Po', 'BsmtCond_TA', 'BsmtExposure_Av',
#        'BsmtExposure_Gd', 'BsmtExposure_Mn', 'BsmtExposure_No',
#        'BsmtFinType1_ALQ', 'BsmtFinType1_BLQ', 'BsmtFinType1_GLQ',
#        'BsmtFinType1_LwQ', 'BsmtFinType1_No', 'BsmtFinType1_Rec',
#        'BsmtFinType1_Unf', 'BsmtFinType2_ALQ', 'BsmtFinType2_BLQ',
#        'BsmtFinType2_GLQ', 'BsmtFinType2_LwQ', 'BsmtFinType2_No',
#        'BsmtFinType2_Rec', 'BsmtFinType2_Unf', 'Heating_Floor',
#        'Heating_GasA', 'Heating_GasW', 'Heating_Grav', 'Heating_OthW',
#        'Heating_Wall', 'HeatingQC_Ex', 'HeatingQC_Fa', 'HeatingQC_Gd',
#        'HeatingQC_Po', 'HeatingQC_TA', 'CentralAir_N', 'CentralAir_Y',
#        'Electrical_FuseA', 'Electrical_FuseF', 'Electrical_FuseP',
#        'Electrical_Mix', 'Electrical_SBrkr', 'KitchenQual_Ex',
#        'KitchenQual_Fa', 'KitchenQual_Gd', 'KitchenQual_TA',
#        'Functional_Maj1', 'Functional_Maj2', 'Functional_Min1',
#        'Functional_Min2', 'Functional_Mod', 'Functional_Sev',
#        'Functional_Typ', 'FireplaceQu_Ex', 'FireplaceQu_Fa',
#        'FireplaceQu_Gd', 'FireplaceQu_No', 'FireplaceQu_Po',
#        'FireplaceQu_TA', 'GarageType_2Types', 'GarageType_Attchd',
#        'GarageType_Basment', 'GarageType_BuiltIn', 'GarageType_CarPort',
#        'GarageType_Detchd', 'GarageType_No', 'GarageFinish_Fin',
#        'GarageFinish_No', 'GarageFinish_RFn', 'GarageFinish_Unf',
#        'GarageQual_Ex', 'GarageQual_Fa', 'GarageQual_Gd', 'GarageQual_No',
#        'GarageQual_Po', 'GarageQual_TA', 'GarageCond_Ex', 'GarageCond_Fa',
#        'GarageCond_Gd', 'GarageCond_No', 'GarageCond_Po', 'GarageCond_TA',
#        'PavedDrive_N', 'PavedDrive_P', 'PavedDrive_Y', 'PoolQC_Ex',
#        'PoolQC_Fa', 'PoolQC_Gd', 'PoolQC_No', 'Fence_GdPrv', 'Fence_GdWo',
#        'Fence_MnPrv', 'Fence_MnWw', 'Fence_No', 'MiscFeature_Gar2',
#        'MiscFeature_No', 'MiscFeature_Othr', 'MiscFeature_Shed',
#        'MiscFeature_TenC', 'MoSold_Apr', 'MoSold_Aug', 'MoSold_Dec',
#        'MoSold_Feb', 'MoSold_Jan', 'MoSold_Jul', 'MoSold_Jun',
#        'MoSold_Mar', 'MoSold_May', 'MoSold_Nov', 'MoSold_Oct',
#        'MoSold_Sep', 'SaleType_COD', 'SaleType_CWD', 'SaleType_Con',
#        'SaleType_ConLD', 'SaleType_ConLI', 'SaleType_ConLw',
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial'], dtype=object)

# %% [markdown]
# ## Partitioning of the Data Set Into Train and Test Set
#
# We are using a 70/30 (training/testing) splitting. (The parameter `random_state=0` fixes the random split in a way such that results are reproducible.)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=42, 
                                                    stratify=y)

# %% [markdown]
# A stratified sample is one that maintains the proportion of values as in the original data set. If, for example, the response vector  𝑦 is a binary categorical variable with 25% zeros and 75% ones, `stratify=y` ensures that the random splits have 25% zeros and 75% ones too. Note that `stratify=y` does not mean `stratify=yes` but rather tells the function to take the categorical proportions from response vector `y`.

# %% [markdown]
# ## Handling Outliers

# %%
out = IsolationForest(random_state = 42).fit(X_train)
out_train = out.predict(X_train)
out_test = out.predict(X_test)


X_train_wout_out = X_train[np.where(out_train == 1, True, False)]
y_train_wout_out = y_train[np.where(out_train == 1, True, False)]
X_test_wout_out = X_test[np.where(out_test == 1, True, False)]
y_test_wout_out = y_test[np.where(out_test == 1, True, False)]

print("Training Set")
print("Shape including outliers: ", X_train.shape)
print("Shape excluding outliers: ", X_train_wout_out.shape)
print("Nr. of outliers removed: ", X_train.shape[0]-X_train_wout_out.shape[0])

print(50*"-")

print("Test Set")
print("Shape including outliers: ", X_test.shape)
print("Shape excluding outliers: ", X_test_wout_out.shape)
print("Nr. of outliers removed: ", X_test.shape[0]-X_test_wout_out.shape[0])
# Out:
# Training Set
# Shape including outliers:  (1022, 324)
# Shape excluding outliers:  (1016, 324)
# Nr. of outliers removed:  6
# --------------------------------------------------
# Test Set
# Shape including outliers:  (438, 324)
# Shape excluding outliers:  (433, 324)
# Nr. of outliers removed:  5

# %%
# Using the data without the outliers for the models

# Traning Set
X_train = X_train_wout_out
y_train = y_train_wout_out

# Test Set
X_test = X_test_wout_out
y_test = y_test_wout_out

# %% [markdown]
# ## Multicollinearity

# %%
## Feature Selection##
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Compute the correlation matrix
#corr = df.corr()

# Plotting Heatmap
#plt.figure(figsize = (10,6))
#sns.heatmap(corr, annot = True)

# %%
# Compute the correlation matrix
#corr_matrix = df.corr()

# Sort the correlations with respect to 'Class'
#corr_with_class = corr_matrix['Class'].sort_values(ascending=False)

# Print the correlations
#print(corr_with_class)

# Select the top 10 features with the highest correlation
#top_features = corr_with_class.nlargest(10).index

# Print the top features
#print(top_features)

# %% [markdown]
# ## Skewness and Normalizing Variables
#
# Linear regression assumes that the data follows a normal distribution, and therefore, transforming skewed data can improve the performance of the models.

# %%
plt.figure(1); plt.title('Distribution of Class')
sns.histplot(data=y, discrete = True)
# Out:
# <Axes: title={'center': 'Distribution of Class'}, xlabel='Class', ylabel='Count'>

# %% [markdown]
# We see that our "Class" deviates from the normal distribution, is positively/right-skewed skewed and shows peakedness (cortosis).

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Class'].skew())
print("Kurtosis: %f" % df['Class'].kurt())
# Out:
# Skewness: 1.100106
# Kurtosis: 1.768369

# %% [markdown]
# To normalize right-skewed data, log transformation can be used as a method since it pulls the larger values towards the center. However, because log(0) results in NaN, log(1+X) is preferred as a fix for the skewness instead.

# %%
sns.displot(data=y, kind='hist', kde=True)
title = plt.title("House Price Distribution")

# %%
y_trafo = np.log(1 + y)
sns.displot(data=y_trafo, kind='hist', kde=True)
title = plt.title("House Price Distribution Transformation")

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# Standardizing the dataset before running machine learning algorithms is generally recommended, except for Decision Tree and Random Forest models. This is because optimization methods and gradient descent algorithms tend to perform and converge faster on features that are similarly scaled.
#
# However, outliers can have a negative impact on the sample mean and standard deviation, and models like Lasso and others are highly sensitive to outliers. In such cases, using the median and interquartile range is a better alternative. For this reason, the StandardScaler method is used to transform the training data.

# %%
from sklearn.preprocessing import MinMaxScaler 

# Get cols to scale
cols_scl = X.columns.values[:]

# Apply MinMaxScaler on continuous columns only (check dummies!!!)
mms = MinMaxScaler()
X_train_norm = mms.fit_transform(X_train[cols_scl])  # fit & transform
X_test_norm  = mms.transform(X_test[cols_scl])  # ONLY transform

# %%
from sklearn.preprocessing import StandardScaler 

# Apply StandardScaler on continuous columns only
stdsc = StandardScaler()
X_train_std = stdsc.fit_transform(X_train[cols_scl])  # fit & transform
X_test_std  = stdsc.transform(X_test[cols_scl])  # ONLY transform

# %% [markdown]
# # Logistic Regression

# %%
################### Feature Scaling with MinMaxScalar #################

# Get cols to scale
cols_scl = X.columns.values[:]

# Apply MinMaxScaler on continuous columns only
mms = MinMaxScaler()
X_train_norm_MMS = mms.fit_transform(X_train)  # fit & transform
X_test_norm_MMS  = mms.transform(X_test)  # ONLY transform

# %%
#################### Feature Scaling with StandartScalar ##################
from sklearn.preprocessing import StandardScaler

#scaling
scaler = StandardScaler()
scaler.fit(X_train)

#transforming 
X_train_norm_STD = scaler.transform(X_train)
X_test_norm_STD = scaler.transform(X_test)

# %%
# Train logistic regression model (using MinMaxStandardization)
lr = LogisticRegression().fit(X_train_norm_MMS,y_train)
y_pred = lr.predict(X_test_norm_MMS)
# Out:
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
report(y_test,y_pred) #Report of LogReg using all features and MinMaxStandardization
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.53      0.57        34
#          1.0       0.86      0.87      0.87       271
#          2.0       0.61      0.69      0.65        94
#          3.0       0.47      0.35      0.40        26
#          4.0       0.80      0.50      0.62         8
#
#     accuracy                           0.77       433
#    macro avg       0.67      0.59      0.62       433
# weighted avg       0.76      0.77      0.76       433

# %%
##### Hyperparametrization of Logistic Regression (using MinMaxStandardization)

#hyperparameters
param_grid_lr_MMS = {
    "solver": ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], # Algorithm to use in the optimization problem.
    "penalty": ["l1","l2"], #specify norm of penalty
    "C": np.logspace(-3,3,15), #smaller values specify stronger regularization    
}

# Run brute-force grid search
lr_grid = GridSearchCV(estimator=LogisticRegression(), #model
                             param_grid=param_grid_lr_MMS, #hyperparameters
                             verbose=1, 
                             cv=10, #number of folds
                             n_jobs=-1) #using all cores of computer

# fitting the model
lr_grid.fit(X_train_norm_MMS, y_train)
y_pred = lr_grid.predict(X_test_norm_MMS)
# Out:
# Fitting 10 folds for each of 150 candidates, totalling 1500 fits
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 18
#      11 lr_grid = GridSearchCV(estimator=LogisticRegression(), #model
#      12                              param_grid=param_grid_lr_MMS, #hyperparameters
#      13                              verbose=1,
#      14                              cv=10, #number of folds
#      15                              n_jobs=-1) #using all cores of computer
#      17 # fitting the model
# ---> 18 lr_grid.fit(X_train_norm_MMS, y_train)
#      19 y_pred = lr_grid.predict(X_test_norm_MMS)
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/opt/anaconda3/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File ~/opt/anaconda3/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
report(y_test,y_pred) #Report of LogReg using all features, MinMaxStandardization and Hyperparametrization of usual LogReg-Parameters

# %%
# Train logistic regression model (using StandardScalar)
lr = LogisticRegression().fit(X_train_norm_STD,y_train)
y_pred = lr.predict(X_test_norm_STD)

# %%
report(y_test,y_pred) #Report of LogReg using StandartScalar Standardization

# %%
##### Hyperparametrization of Logistic Regression (using StandardScalar)

#hyperparameters
param_grid_lr_STD = {
    "solver": ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], # Algorithm to use in the optimization problem.
    "penalty": ["l1","l2"], #specify norm of penalty
    "C": np.logspace(-3,3,10), #smaller values specify stronger regularization    
}
# Run brute-force grid search
lr_grid = GridSearchCV(estimator=LogisticRegression(), #model
                             param_grid=param_grid_lr_STD, #hyperparameters
                             verbose=1, 
                             cv=10, #number of folds
                             n_jobs=-1) #using all cores of computer
# fitting the model
lr_grid.fit(X_train_norm_STD, y_train)

y_pred = lr_grid.predict(X_test_norm_STD)

# %%
report(y_test,y_pred) #Report of LogReg usuing StandartScalar Standardization and Hyperparametrization

# %%
################################## Random Forest Feature Selection for Logistic Regression##########################################

sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train_norm_STD,y_train)
sel.get_support
selected_feat= X_train.columns[(sel.get_support())]

# %%
# Data set with just Random Forest Features
X_train_rf = X_train[selected_feat]
X_test_rf = X_test[selected_feat]

#Feature Scaling using StandardScalar
scaler = StandardScaler()
scaler.fit(X_train_rf)
X_train_rf_STD = scaler.transform(X_train_rf)
X_test_rf_STD= scaler.transform(X_test_rf)

# %%
#Logistic Regression
logModel_rf = LogisticRegression().fit(X_train_rf_STD,y_train)
y_pred_rf = logModel_rf.predict(X_test_rf_STD)

# %%
report(y_test,y_pred_rf) #Report of LogReg usuing StandartScalar Standardization and Random Forest Feature Selection

# %%
# Hyperparametrization on Model using Random Forest Feature Selection

#hyperparameters
param_grid_lr_rf = {
    "solver": ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], # Algorithm to use in the optimization problem.
    "penalty": ["l1","l2"], #specify norm of penalty
    "C": np.logspace(-3,3,15), #smaller values specify stronger regularization    
}

lr_rf_grid = GridSearchCV(estimator=LogisticRegression(),
                          param_grid=param_grid_lr_rf,
                          cv = 10,
                          n_jobs=-1
                          )
lr_rf_grid.fit(X_train_rf_STD,y_train)
y_pred_rf = logModel_rf.predict(X_test_rf_STD)

# %%
report(y_test,y_pred) #Report of LogReg using StandartScalar Standardization, Random Forest Feature Selection and Hyperparam

# %%
############### XGBoost Feature Selection for Logistic Regression ########################
# Notice that the coding process is analogous to Random Forest Feature Selection
xgbc= xgb.XGBClassifier( objective = "multi:softmax", random_state = 42)
select_xgbc = SelectFromModel(estimator = xgbc, threshold = "median")
select_xgbc.fit(X_train, y_train)

list_train_xgbc= X_train.columns[(select_xgbc.get_support())]
list_test_xgbc= X_test.columns[(select_xgbc.get_support())]

X_train_xgbc = X_train[list_train_xgbc]
X_test_xgbc = X_test[list_test_xgbc]

# %%
scaler = StandardScaler()
scaler.fit(X_train_xgbc)

X_train_xgbc_STD = scaler.transform(X_train_xgbc)
X_test_xgbc_STD= scaler.transform(X_test_xgbc)

# %%
logModel_xgbc = LogisticRegression().fit(X_train_xgbc_STD,y_train)
y_pred_xgbc = logModel_xgbc.predict(X_test_xgbc_STD)

# %%
report(y_test,y_pred_xgbc)

# %%
################# PCA Dimension Reduction on LogReg #########################

# Scale the data using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a PCA object and fit it to the scaled data
pca = PCA(n_components=3) # Select the number of components you want to keep
pca.fit(X_train_scaled)

# Transform the data to the selected number of components
X_train_pca = pca.transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Train the logistic regression model on the transformed data
logModel_pca = LogisticRegression().fit(X_train_pca, y_train)
y_pred_pca = logModel_pca.predict(X_test_pca)

# %%
report(y_test,y_pred_pca) #Results on PCA for LogReg

# %% [markdown]
# #### Summary on Logistic Regression
#
# #### Using MinMaxScalar
# We find the following Scores:
# f1 Score:         0.78
#
# #### Using MinMaxScalar and hyperparametrization
# We find the following Scores:
# f1 Score:         0.81
#
# #### Using StandardScalar
# We find the following Scores:
# f1 Score:         0.76
#
# #### Using StandardScalar and hyperparametrization
# We find the following Scores:
# f1 Score:         0.82
#
# #### Using StandardScaler and  RandomForest Feature Selection
# We find the following Scores:
# f1 Score:         0.83
#
# #### Using StandardScaler, RandomForest Feature Selection and Hyperparametrization
# We find the following Scores:
# f1 Score:         0.82
#
# #### Using StandardScaler and XBoost:
# We find the following Scores:
# f1 Score:         0.80
#
# #### Using StandardScaler and PCA
# We find the following Scores:
# f1 Score:         0.75

# %% [markdown]
# # KNN

# %%
#KNN-Model##
train_df = pd.DataFrame(data=X_train, columns=X.columns)
train_df['Class'] = y_train

test_df = pd.DataFrame(data=X_test, columns=X.columns)
test_df['Class'] = y_test

X_train = train_df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
y_train = train_df['Class']

# Initialize the KNN classifier with k=20
knn = KNeighborsClassifier(n_neighbors=20)

# Fit the KNN model on the training data
knn.fit(X_train, y_train)

# Use the trained KNN model to make predictions on the test data
X_test = test_df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
y_test = test_df['Class']
y_pred = knn.predict(X_test)

# Compute the accuracy of the KNN model on the test data
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Compute the classification report for the KNN model on the test data
report = classification_report(y_test, y_pred)
print(report)
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# The model correctly classified 78% of the instances in the test set.
# The report indicates that the model performs well in predicting class 1, with a precision of 0.85 and a recall of 0.89, indicating that it correctly predicted a high proportion of the instances belonging to this class. However, the model performed less well in predicting classes 0 and 3.

# %% [markdown]
# ## Class Imbalance

# %%
###KNN-SMOTE####
# Create SMOTE object
smote = SMOTE(random_state=42)

# Fit SMOTE on the training data
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Print the number of samples before and after SMOTE
print("Number of samples before SMOTE:", len(X_train))
print("Number of samples after SMOTE:", len(X_train_smote))

# Train a KNN classifier on the oversampled data
knn_smote = KNeighborsClassifier(n_neighbors=20)
knn_smote.fit(X_train_smote, y_train_smote)

# Predict the test set using the KNN classifier trained on the oversampled data
y_pred_smote = knn_smote.predict(X_test)

# Compute the accuracy of the KNN model with SMOTE on the test data
accuracy_smote = accuracy_score(y_test, y_pred_smote)
print("Accuracy with SMOTE:", accuracy_smote)

# Compute the classification report for the KNN model with SMOTE on the test data
report_smote = classification_report(y_test, y_pred_smote)

# Print the classification report
print(report_smote)
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# SMOTE is used to address class imbalance by creating synthetic samples. However, in this case, after oversampling with SMOTE, the performance of the KNN classifier on the test set actually got worse compared to the previous results without SMOTE. The accuracy dropped from 0.7534 to 0.621, and the overall classification report shows lower precision and recall scores for some classes.
# This could be due to overfitting on the training data or other factors

# %%
##Class Imbalance using Random Oversample
# Initialize the random oversampler with random_state=0
ros = RandomOverSampler(random_state=0)

# Resample the training data
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Initialize the KNN classifier with k=20
knn = KNeighborsClassifier(n_neighbors=20)

# Fit the KNN model on the resampled training data
knn.fit(X_train_resampled, y_train_resampled)

# Use the trained KNN model to make predictions on the test data
y_pred = knn.predict(X_test)

# Compute the accuracy of the KNN model on the test data
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy with RandomOverSampler:", accuracy)

# Compute the classification report for the KNN model on the test data
report = classification_report(y_test, y_pred)

# Print the classification report
print(report)
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# RandomOverSampler technique to address the class imbalance in the training data. The accuracy of the model after using Random Oversampling is 0.589. The drop in accuracy could be due to the fact that the synthetic samples generated by Random Oversampling can add noise to the data, leading to overfitting.

# %%
# Define features and target variable

X = df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
y = df['Class']

# Create KNN object and run classifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X, y)

# Predict probabilities for each class
y_prob = knn.predict_proba(X)

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(set(y))):
    fpr[i], tpr[i], _ = roc_curve(y, y_prob[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure()
colors = ['red', 'green', 'blue', 'orange', 'purple']
for i, color in zip(range(len(set(y))), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # LDA

# %%
# feature atrix X and target variable Y
X = df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
Y = df['Class']

# Train-Test-Split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# LDA-Modell
lda = LDA(solver='lsqr')
lda.fit(X_train, y_train)

# Prediction
y_pred = lda.predict(X_test)

# performance
print('default-rate: {0: .4f}'.format(np.sum(y_test)/len(y_test)))

report = classification_report(y_test, y_pred)
print(report)

# confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# In this specific case, the default rate is 1.29, which means that the most frequent class in the test set is Class 1. The F1-score is 0.79, which indicates that the model has good accuracy. The classification report shows precision, recall, and F1-score for each class.

# %% [markdown]
# ## Class Imbalance

# %%
###SMOTE###
# Feature-Matrix X und Zielvariable Y auswählen
X = df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
Y = df['Class']

# Train-Test-Split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Apply SMOTE to training data
sm = SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# LDA-Modell erstellen und anpassen
lda = LDA(solver='lsqr')
lda.fit(X_train_res, y_train_res)

# Vorhersagen auf Testdaten machen
y_pred = lda.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)

# Konfusionsmatrix ausgeben
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# Here, we have also tried to address the class imbalancing problem by applying SMOTE. But this also led to a deterioration of the model.

# %%
# Define features and target variable
X = df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
y = df['Class']

# Create LDA object and run classifier
lda = LDA(solver='lsqr')
lda.fit(X, y)

# Predict probabilities for each class
y_prob = lda.predict_proba(X)

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(set(y))):
    fpr[i], tpr[i], _ = roc_curve(y, y_prob[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure()
colors = ['red', 'green', 'blue', 'orange', 'purple']
for i, color in zip(range(len(set(y))), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # QDA

# %%
####QDA
# Feature-Matrix X und Zielvariable Y auswählen
X = df[['Class', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
      "totalSqFeet" , 'TotRmsAbvGrd',"totalBathroom"]]
Y = df['Class']

# Train-Test-Split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# QDA-Modell erstellen und anpassen
qda = QDA()
qda.fit(X_train, y_train)

# Vorhersagen auf Testdaten machen
y_pred = qda.predict(X_test)

# Konfusionsmatrix ausgeben
print(classification_report(y_test, y_pred))
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# The model achieves an accuracy of 0.82, and the precision and recall vary across the classes, with the highest precision and recall achieved for class 1.0.

# %% [markdown]
# # Decision Trees / Random Forest

# %% [markdown]
# ## Decision Trees

# %%
# Initializing decision tree
tree = DecisionTreeClassifier(max_depth=4, random_state = 42)
tree.fit(X_train, y_train)

# Performance metrics for training and test set
print('Train score: ', tree.score(X_train, y_train))
print('Test score: ', tree.score(X_test, y_test))

print(70*'-')

# Confusion matrix
y_pred = tree.predict(X_test)
print('Confusion matrix for Decision Tree: \n')
print("Left = Predicted; Top = Actual")
print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# We see that 3 were predicted to be in class 4 but were actually in class 2. On was predicted to be in class 4 but was actually in class 1.

# %% [markdown]
# ### Visualizing Decision Tree
# [Scikit-learn website for details.](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html).

# %%
# Plot tree
plt.figure(figsize=(40, 23))
plot_tree(tree, filled=True, feature_names = list(X.columns), rounded=True, class_names=["0", "1", "2", "3", "4"],);

# %% [markdown]
# ### Grid Search (Finding Hyperparameters)
# Evaluates the model performance for each combination of hyperparameter to obtain the optimal combination of values from this set (Raschka (2015)).

# %%
# get a list of all possible parameters
print(f"Parameters of the Decision Tree: {tree.get_params().keys()}")

# %%
# k-Fold CV object (k = 5)
kFold = StratifiedKFold(n_splits=5)


####### Parameters of the Decision Tree under investigation #######

# In the initial tuning we included more values.
# But more values cause more computational effort.
# We only have a preselected list of values that include values around the best value.


##### Estimators #####

# Criterion
# The function to measure the quality of a split.
Criterion = np.array(["gini", "entropy"])

# Splitter 
# The strategy used to choose the split at each node.
Splitter = np.array(["best", "random"])

# Class weight
# Weights associated with classes in the form {class_label: weight}.
class_Weight = np.array([None, "balanced", "balanced_subsample"])

# Max depth
# The maximum depth of the tree. 
maxDepth = np.array([1, 5, 7, 8, 9, 10, 11, 12, 15, 18])

# Max features
# The number of features to consider when looking for the best split.
max_Features = np.array([None, "auto", "sqrt", "log2"])

# min_Samples_Split
# The minimum number of samples required to split an internal node.
min_Samples_Split = np.array([1, 2, 3, 4, 5])

# minSamplesLeaf
minSamplesLeaf = np.array([1, 2, 3, 4, 5])

# %%
# hyperparameter to be tested
param_grid_tr = {"class_weight": class_Weight,
              #"criterion": Criterion,
              "max_depth": maxDepth,
              #"splitter": Splitter,
              #"max_features": max_Features,
              "min_samples_split": min_Samples_Split,
              "min_samples_leaf": minSamplesLeaf,
}

# grid search
tree_gs = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42, max_features = "sqrt"),
                  param_grid=param_grid_tr,
                  scoring="accuracy",
                  cv=kFold, n_jobs=-1)
tree_gs = tree_gs.fit(X_train, y_train)

print("Performance of Decision Tree")
print_results_crossvalidation(tree_gs, X_test, y_test)
y_pred = tree_gs.best_estimator_.predict(X_test)
report(y_test, y_pred)

# %%
# Take best parameter
clf = tree_gs.best_estimator_

# Fitting the model with the best parameter
clf.fit(X_train, y_train)

# Print out score on Test dataset
print("Accuracy Test Set: {0: .4f}".format(clf.score(X_test, y_test)))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Grid Search (Finding Hyperparameters)
# Evaluates the model performance for each combination of hyperparameter to obtain the optimal combination of values from this set (Raschka (2015)).

# %%
# Initializing Classifier object
forest = RandomForestClassifier(n_estimators = 100, criterion="gini", random_state=42, n_jobs=-1)

# Get a list of all parameters of random forest
print(f"Parameters of Random Forest: {forest.get_params().keys()}")

# %%
# k-Fold CV object (k = 5)
kFold = StratifiedKFold(n_splits=5)


####### Parameters for the Random Forest #######

# In the initial tuning we included more values.
# But more values cause more computational effort.
# We only have a preselected list of values that include values around the best value.


##### Estimators #####

# The number of trees in the forest.
n_Estimators = np.array([90, 95, 100, 105])

# Criterion
# The function to measure the quality of a split.
Criterion = np.array(["gini", "entropy"])

# Class weight
# Weights associated with classes in the form {class_label: weight}.
class_Weight = np.array([None, "balanced", "balanced_subsample"])

# Max depth
# The maximum depth of the tree. 
maxDepth = np.array([5, 10, 15, 20])

# Max features
# The number of features to consider when looking for the best split.
max_Features = np.array([None, "auto", "sqrt", "log2"])

# min_Samples_Split
# The minimum number of samples required to split an internal node.
min_Samples_Split = np.array([2, 3, 4])

# minSamplesLeaf
minSamplesLeaf = np.array([1, 2, 3])

# Bootstrap
BootStrap = np.array(["False", "True"])

# %%
# hyperparameter to be tested (for computational reasons those where the default is the best are hashtaged)
param_grid_fo = {
              #"class_weight": class_Weight,
              #"criterion": Criterion,
              "n_estimators": n_Estimators,
              "max_depth": maxDepth,
              #"max_features": max_Features,
              "min_samples_split": min_Samples_Split,
              "min_samples_leaf": minSamplesLeaf,
              #"bootstrap": BootStrap
}

# grid search
forest_gs = GridSearchCV(estimator=RandomForestClassifier(random_state=0, n_jobs=-1, max_features = "sqrt"),
                  param_grid=param_grid_fo,
                  scoring="accuracy",
                  cv=kFold, n_jobs=-1)
forest_gs = forest_gs.fit(X_train, y_train)

print("Performance of Random Forest")
print_results_crossvalidation(forest_gs, X_test, y_test)
y_pred = forest_gs.best_estimator_.predict(X_test)

#report(y_test, y_pred)

# %%
# Take best parameter
clf = forest_gs.best_estimator_

# Fitting the model with the best parameter
clf.fit(X_train, y_train)

# Print out score on Test dataset
print("Accuracy Test Set: {0: .4f}".format(clf.score(X_test, y_test)))

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# The objective of the support vector machine algorithm is to find a hyperplane in an N-dimensional space(N — the number of features) that distinctly classifies the data points.
#
# Support vector machines (SVMs) are a type of supervised learning algorithm that can be utilized for tasks such as classification, regression, and outlier detection. One of the key benefits of SVMs is their effectiveness in handling high-dimensional data, as well as cases where the number of dimensions exceeds the number of samples. Additionally, SVMs are memory-efficient due to their use of a subset of training points, referred to as "support vectors," in the decision-making process. Moreover, SVMs are highly versatile, as they can incorporate different kernel functions to specify the decision function, with the option to define custom kernels. It's important to acknowledge that SVMs come with their own set of limitations. One such limitation arises when dealing with datasets where the number of features far exceeds the number of samples; in such cases, it is essential to exercise caution in selecting kernel functions and regularization terms to prevent over-fitting. Another limitation of SVMs is that they do not offer direct probability estimates, which necessitates the use of a time-consuming five-fold cross-validation method to calculate them.

# %% [markdown]
# ## SVM
#
# First, we will train our model by calling the standard SVC() function without doing Hyperparameter Tuning and see its classification and confusion matrix.

# %%
# The SVC Class from Sklearn
svm1= svm.SVC(
        C=1.0,                          # The regularization parameter
        kernel='rbf',                   # The kernel type used 
        degree=3,                       # Degree of polynomial function 
        gamma='scale',                  # The kernel coefficient
        coef0=0.0,                      # If kernel = 'poly'/'sigmoid'
        shrinking=True,                 # To use shrinking heuristic
        probability=False,              # Enable probability estimates
        tol=0.001,                      # Stopping crierion
        cache_size=200,                 # Size of kernel cache
        class_weight=None,              # The weight of each class
        verbose=False,                  # Enable verbose output
        max_iter= -1,                   # Hard limit on iterations
        decision_function_shape='ovr',  # One-vs-rest or one-vs-one
        break_ties=False,               # How to handle breaking ties
        random_state=42               # Random state of the model
    )

print(f"Parameters of the Support Vector Machine: {svm1.get_params().keys()}")
# Out:
# Parameters of the Support Vector Machine: dict_keys(['C', 'break_ties', 'cache_size', 'class_weight', 'coef0', 'decision_function_shape', 'degree', 'gamma', 'kernel', 'max_iter', 'probability', 'random_state', 'shrinking', 'tol', 'verbose'])

# %%
# Building and training our model
clf = svm1.fit(X_train, y_train)

# Making predictions with our data
predictions = clf.predict(X_test)

# Model Accuracy: how often is the classifier correct?
print("Accurancy:", accuracy_score(y_test, predictions))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:", precision_score(y_true= y_test, y_pred= predictions, average= 'weighted')) # WEIGHTED???? 

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:", recall_score(y_test, predictions, average= 'weighted'))  # WEIGHTED???? 

#Whole classification report
print(classification_report(y_test, predictions))
# Out:
# Accurancy: 0.648960739030023
# Precision: 0.4999987726037297
# Recall: 0.648960739030023
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        34
#          1.0       0.69      0.98      0.81       271
#          2.0       0.31      0.16      0.21        94
#          3.0       0.00      0.00      0.00        26
#          4.0       0.00      0.00      0.00         8
#
#     accuracy                           0.65       433
#    macro avg       0.20      0.23      0.20       433
# weighted avg       0.50      0.65      0.55       433
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Notice that recall and precision for class 0, 3 and 4 are always 0. It means that the classifier is always classifying everything into class 1 and 2! This means our model needs to have its parameters tuned.
# Here is when the usefulness of GridSearch comes into the picture. We can search for parameters using GridSearch!

# %% [markdown]
# ## Scaling/Pipeline
#
# Support Vector Machine algorithms are not scale invariant, so it is highly recommended to scale your data. For example, scale each attribute on the input vector X to [0,1] or [-1,+1], or standardize it to have mean 0 and variance 1. Note that the same scaling must be applied to the test vector to obtain meaningful results. This can be done easily by using a Pipeline:

# %%
scaler = StandardScaler()
mms = MinMaxScaler()

ros = RandomOverSampler(random_state = 42)
kFold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 42)

# %%
svm_pipe = imbpipeline(steps=[["scaler", scaler], ["ros", ros], ["SVM", svm1]])
param_grid = {
    'ros': [ros, None], 
    'scaler': [scaler, mms],
    "SVM__kernel": ["linear", "sigmoid", "rbf"],
    "SVM__C": [1, 5, 10, 50],
    "SVM__gamma": ["auto", "scale"]
}

# %% [markdown]
# #### GridSearch
#
# SVM has hyper-parameters such as C or gamma values that can greatly impact its performance. However, determining the optimal hyper-parameters can be a difficult task. One way to do so is by exploring various combinations of hyper-parameters to identify the ones that work best.
#
# Often one uses Gridsearch, which involves creating a grid of hyper-parameters and trying out all possible combinations to determine the optimal set of values.

# %%
gs = GridSearchCV(estimator = svm_pipe, param_grid = param_grid, scoring = "f1_weighted",
                  cv = kFold, n_jobs = -1, refit = True, verbose = 5)

# %% [markdown]
# The process performed by "fit" is more complex.
# Initially, it executes the same loop using cross-validation to identify the most optimal combination of parameters.
# After it determines the best combination, it proceeds to execute "fit" again on all the data that was passed to it (without implementing cross-validation).
# This second "fit" run is aimed at constructing a single new model utilizing the finest parameter setting identified in the first step.

# %%
gs = gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits

# %% [markdown]
# You can inspect the best parameters found by GridSearchCV in the best_params_ attribute,
# and the best estimator in the best_estimator_ attribute

# %%
# %time gs.fit(X_train, y_train)
print_results_crossvalidation(gs, X_test, y_test)
y_pred = gs.best_estimator_.predict(X_test)

report(y_test, y_pred)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# CPU times: user 4.23 s, sys: 370 ms, total: 4.6 s
# Wall time: 42.5 s
# Best parameters: {'SVM__C': 10, 'SVM__gamma': 'scale', 'SVM__kernel': 'rbf', 'ros': RandomOverSampler(random_state=42), 'scaler': MinMaxScaler()}
# Mean CV score: 0.7986858314233147
# Standard deviation of CV score: 0.020171690218989912
# Test Score:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.53      0.58        34
#          1.0       0.90      0.88      0.89       271
#          2.0       0.69      0.79      0.73        94
#          3.0       0.50      0.46      0.48        26
#          4.0       0.67      0.50      0.57         8
#
#     accuracy                           0.80       433
#    macro avg       0.68      0.63      0.65       433
# weighted avg       0.80      0.80      0.80       433

# %% [markdown]
# #### Precision, Recall and F1-Score
#
# Precision (positive predicted) is the fraction of relevant data among the retrieved data. On the other hand, recall (sensitivity) is the fraction of relevant data that were retrieved. Both precision and recall are based on relevance.
#
#
# In practice, when we try to increase the precision of our model, the recall goes down, and vice-versa. The F1-score captures both the trends in a single value.
#
# The column “support” represents the number of samples that were present in each class of the test set.

# %% [markdown]
# #### Confusion Matrix
#
# Rows represent the expected class labels, and columns represent the predicted class labels. To use the heatmap, it is wiser to use a normalized confusion matrix because the dataset may be imbalanced.

# %% [markdown]
# ### Random Forest Feature Selection ###

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

## Feature Selection using Random Forest for outside of pipeline
sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train, y_train)
sel.get_support()
list_train_rf= X_train.columns[(sel.get_support())]
list_test_rf= X_test.columns[(sel.get_support())]

print(list_train_rf)

X_train_rf = X_train[list_train_rf]
X_test_rf = X_test[list_test_rf]
# Out:
# Index(['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'GrLivArea', 'BedroomAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'YrSold', 'totalSqFeet',
#        'totalBathroom', 'houseAge', 'reModeled', 'CentralAirFac',
#        'MSSubClass_SC30', 'MSSubClass_SC60', 'MSZoning_RL', 'LotShape_IR1',
#        'LotShape_Reg', 'Neighborhood_NridgHt', 'HouseStyle_2Story',
#        'RoofStyle_Gable', 'Exterior2nd_CmentBd', 'Exterior2nd_VinylSd',
#        'MasVnrType_No', 'ExterQual_Ex', 'ExterQual_Gd', 'ExterQual_TA',
#        'Foundation_CBlock', 'Foundation_PConc', 'BsmtQual_Ex', 'BsmtQual_Gd',
#        'BsmtQual_TA', 'BsmtExposure_Gd', 'BsmtExposure_No', 'BsmtFinType1_GLQ',
#        'HeatingQC_Ex', 'CentralAir_N', 'CentralAir_Y', 'KitchenQual_Ex',
#        'KitchenQual_Gd', 'KitchenQual_TA', 'FireplaceQu_Gd', 'FireplaceQu_No',
#        'GarageType_Detchd', 'GarageType_No', 'GarageFinish_Fin',
#        'GarageFinish_RFn', 'GarageFinish_Unf', 'GarageQual_TA',
#        'GarageCond_No', 'GarageCond_TA', 'SaleType_New'],
#       dtype='object')

# %%
pd.Series(sel.estimator_.feature_importances_.ravel()).hist()


importances = sel.estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
# X is the train data used to fit the model 
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
svm2= svm.SVC(random_state = 42, max_iter = -1)
pipe = imbpipeline(steps=[["scaler", scaler],["ros", ros], ["SVM", svm2]])

param_grid= {
    "scaler": [scaler, mms],
    "ros": [ros, None],
    "SVM__kernel": ["linear", "sigmoid", 'rbf'],
    "SVM__C": [1, 5, 10, 50],
    "SVM__gamma": ["auto", "scale"]
}
gs = GridSearchCV(estimator = pipe, param_grid = param_grid, scoring = "f1_weighted", cv = kFold, n_jobs = -1)
gs = gs.fit(X_train_rf, y_train)

# %time gs.fit(X_train_rf, y_train)
print_results_crossvalidation(gs, X_test_rf, y_test)
y_pred = gs.best_estimator_.predict(X_test_rf)

report(y_test, y_pred)
print("Here!")
# Out:
# CPU times: user 928 ms, sys: 61.7 ms, total: 989 ms
# Wall time: 18.1 s
# Best parameters: {'SVM__C': 5, 'SVM__gamma': 'auto', 'SVM__kernel': 'rbf', 'ros': None, 'scaler': StandardScaler()}
# Mean CV score: 0.81786392117863
# Standard deviation of CV score: 0.04673948506067972
# Test Score:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.71      0.74        34
#          1.0       0.90      0.92      0.91       271
#          2.0       0.73      0.77      0.75        94
#          3.0       0.59      0.50      0.54        26
#          4.0       0.80      0.50      0.62         8
#
#     accuracy                           0.84       433
#    macro avg       0.76      0.68      0.71       433
# weighted avg       0.84      0.84      0.84       433
#
# Here!

# %% [markdown]
# ### XGBoost Feature Selection

# %%
import xgboost as xgb
from sklearn.feature_selection import SelectFromModel

## Feature Selection using XGBoost for outside of pipeline
xgbc= xgb.XGBClassifier( objective = "multi:softmax", random_state = 42)
select_xgbc = SelectFromModel(estimator = xgbc, threshold = "median")
select_xgbc.fit(X_train, y_train)

list_train_xgbc= X_train.columns[(select_xgbc.get_support())]
list_test_xgbc= X_test.columns[(select_xgbc.get_support())]


X_train_xgbc = X_train[list_train_xgbc]
X_test_xgbc = X_test[list_test_xgbc]

# %%
svm3 = svm.SVC(random_state = 42, max_iter = -1)
pipe = imbpipeline(steps=[["scaler", scaler],["ros", ros], ["SVM", svm3]])

param_grid= {
    "scaler": [scaler, mms],
    "ros": [ros, None],
    "SVM__kernel": ["linear", "sigmoid", 'rbf'],
    "SVM__C": [1, 5, 10, 50],
    "SVM__gamma": ["auto", "scale"]
}
gs = GridSearchCV(estimator = pipe, param_grid = param_grid, scoring = "f1_weighted", cv = kFold, n_jobs = -1)
gs = gs.fit(X_train_xgbc, y_train)

# %time gs.fit(X_train_xgbc, y_train)
print_results_crossvalidation(gs, X_test_xgbc, y_test)
y_pred = gs.best_estimator_.predict(X_test_xgbc)

report(y_test, y_pred)
# Out:
# CPU times: user 4.25 s, sys: 369 ms, total: 4.61 s
# Wall time: 41.6 s
# Best parameters: {'SVM__C': 10, 'SVM__gamma': 'scale', 'SVM__kernel': 'rbf', 'ros': RandomOverSampler(random_state=42), 'scaler': MinMaxScaler()}
# Mean CV score: 0.7986858314233147
# Standard deviation of CV score: 0.020171690218989912
# Test Score:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.53      0.58        34
#          1.0       0.90      0.88      0.89       271
#          2.0       0.69      0.79      0.73        94
#          3.0       0.50      0.46      0.48        26
#          4.0       0.67      0.50      0.57         8
#
#     accuracy                           0.80       433
#    macro avg       0.68      0.63      0.65       433
# weighted avg       0.80      0.80      0.80       433

# %% [markdown]
# ### PCA Dimension Reduction

# %%
from sklearn.decomposition import PCA

svm4 = svm.SVC(random_state = 42, max_iter = -1, shrinking = True, kernel = "sigmoid", C = 1)
pca = PCA()

svm_pipe = imbpipeline(steps=[["scaler", scaler], ["pca", pca], ["ros", ros], ["SVM", svm4]])
param_grid = {
    'ros': [ros, None], 
    'scaler': [scaler, mms],
    "SVM__gamma": ["auto", "scale"],
    "pca__n_components": np.arange(4, 10, 1)
}
gs = GridSearchCV(estimator = svm_pipe, param_grid = param_grid, scoring = "f1_weighted",
                  cv = kFold, n_jobs = -1)
gs = gs.fit(X_train, y_train)

# %time gs.fit(X_train, y_train)
print_results_crossvalidation(gs, X_test, y_test)
y_pred = gs.best_estimator_.predict(X_test)

report(y_test, y_pred)
# Out:
# CPU times: user 993 ms, sys: 328 ms, total: 1.32 s
# Wall time: 3.01 s
# Best parameters: {'SVM__gamma': 'scale', 'pca__n_components': 9, 'ros': None, 'scaler': StandardScaler()}
# Mean CV score: 0.6895479975101616
# Standard deviation of CV score: 0.02010873215566101
# Test Score:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.35      0.39        34
#          1.0       0.81      0.86      0.83       271
#          2.0       0.58      0.54      0.56        94
#          3.0       0.43      0.46      0.44        26
#          4.0       0.00      0.00      0.00         8
#
#     accuracy                           0.71       433
#    macro avg       0.45      0.44      0.44       433
# weighted avg       0.69      0.71      0.70       433
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/selinawaber/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.781 total time=   0.9s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.691 total time=   8.3s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   1.2s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.707 total time=   5.4s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.780 total time=   0.9s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.713 total time=   1.7s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.708 total time=   3.9s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.698 total time=   1.6s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.814 total time=   2.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   0.8s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.766 total time=   0.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.784 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.797 total time=   2.8s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.732 total time=   0.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   0.9s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.759 total time=   0.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.771 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.798 total time=   2.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.764 total time=   0.4s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.714 total time=   1.0s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.754 total time=   2.0s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.711 total time=   0.9s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.776 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.771 total time=   2.0s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.782 total time=   0.5s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.711 total time=   3.2s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.682 total time=   6.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.4s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.793 total time=   4.2s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.717 total time=   0.6s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.745 total time=   1.2s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.738 total time=   0.4s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.788 total time=   3.0s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.748 total time=   0.6s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   0.9s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.725 total time=   3.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.735 total time=   0.6s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.750 total time=   1.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.784 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.797 total time=   2.8s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.732 total time=   0.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.740 total time=   1.2s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.771 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.798 total time=   2.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.764 total time=   0.4s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.714 total time=   1.2s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.754 total time=   2.2s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.711 total time=   1.0s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.776 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.771 total time=   2.1s
# [CV 1/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.733 total time=   1.2s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.747 total time=   0.5s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.517 total time=   0.5s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.760 total time=   4.5s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.647 total time=   0.7s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.763 total time=   1.7s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.4s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.793 total time=   0.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.672 total time=   3.3s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.750 total time=   1.3s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.807 total time=   0.9s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.756 total time=   0.7s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.3s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.785 total time=   0.3s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.732 total time=   4.7s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   1.0s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.745 total time=   0.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.702 total time=   3.6s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.766 total time=   0.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.722 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.743 total time=   3.6s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.768 total time=   0.4s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.801 total time=   1.1s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.755 total time=   0.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.771 total time=   0.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.748 total time=   2.3s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.785 total time=   1.2s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.715 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.758 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.802 total time=   1.7s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.785 total time=   1.2s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.705 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.706 total time=   0.3s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.795 total time=   1.9s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.752 total time=   1.3s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.506 total time=   0.5s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.730 total time=   4.2s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.742 total time=   0.7s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.634 total time=   0.7s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.733 total time=   1.6s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.741 total time=   3.1s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.741 total time=   3.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.683 total time=   1.5s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.781 total time=   1.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.804 total time=   1.2s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.735 total time=   0.7s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.9s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.696 total time=   1.7s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.776 total time=   2.2s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.801 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.767 total time=   3.5s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.733 total time=   0.5s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.750 total time=   1.2s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.716 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.726 total time=   0.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.822 total time=   2.1s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   0.8s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.774 total time=   2.1s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.754 total time=   0.7s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   1.0s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.720 total time=   1.2s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.797 total time=   2.1s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.792 total time=   0.4s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.737 total time=   0.4s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.699 total time=   3.3s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.704 total time=   6.4s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.785 total time=   0.4s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.635 total time=   0.5s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.758 total time=   4.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   0.9s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.723 total time=   0.3s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.733 total time=   4.8s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   1.0s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.695 total time=   3.5s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.6s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.780 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.739 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.699 total time=   3.5s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.6s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.801 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.728 total time=   1.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.797 total time=   1.1s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.793 total time=   0.8s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.805 total time=   0.4s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.727 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.726 total time=   0.4s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.745 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.799 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.769 total time=   1.7s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.727 total time=   1.2s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.754 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.792 total time=   2.1s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.758 total time=   0.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.753 total time=   0.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.713 total time=   7.9s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.775 total time=   0.3s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.737 total time=   0.3s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.713 total time=   5.4s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.783 total time=   0.6s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.755 total time=   1.3s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.687 total time=   0.4s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.807 total time=   3.0s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.769 total time=   0.6s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.745 total time=   1.1s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.737 total time=   0.4s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.710 total time=   0.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.763 total time=   2.6s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.9s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.715 total time=   1.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.721 total time=   2.9s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.780 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.739 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.692 total time=   2.9s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.796 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.786 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.786 total time=   2.0s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.719 total time=   0.7s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   1.0s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.726 total time=   1.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.778 total time=   2.0s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.775 total time=   0.3s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.740 total time=   0.4s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.721 total time=   3.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.711 total time=   6.6s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.653 total time=   0.4s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.807 total time=   4.3s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.689 total time=   0.5s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.790 total time=   1.1s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.787 total time=   0.4s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.720 total time=   0.4s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.748 total time=   3.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.787 total time=   0.5s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.790 total time=   1.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.794 total time=   0.4s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.748 total time=   0.4s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.755 total time=   2.6s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   0.8s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.684 total time=   1.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.721 total time=   3.0s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.739 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.692 total time=   3.0s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.796 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.741 total time=   0.4s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.696 total time=   1.2s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.787 total time=   0.9s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.828 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   0.9s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.720 total time=   1.1s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.797 total time=   1.9s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.778 total time=   0.1s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.740 total time=   1.2s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.791 total time=   0.4s
# [CV 1/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.800 total time=   4.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.756 total time=   0.7s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.782 total time=   1.6s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   1.2s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.707 total time=   5.3s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.9s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.706 total time=   1.5s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.703 total time=   3.6s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.3s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.740 total time=   0.3s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.702 total time=   3.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.794 total time=   0.5s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.744 total time=   0.4s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.717 total time=   1.4s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.792 total time=   1.1s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.805 total time=   1.1s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.5s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.726 total time=   1.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.765 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.753 total time=   2.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.741 total time=   1.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.795 total time=   0.4s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.800 total time=   2.1s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.727 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.730 total time=   0.4s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.731 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.713 total time=   0.4s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.795 total time=   2.1s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   1.2s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.791 total time=   0.5s
# [CV 1/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.800 total time=   4.6s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.742 total time=   0.8s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.635 total time=   0.7s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   1.6s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.775 total time=   0.3s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.750 total time=   3.0s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.767 total time=   3.4s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.741 total time=   0.3s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.766 total time=   4.6s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.717 total time=   0.4s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.755 total time=   1.3s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.755 total time=   0.5s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.799 total time=   2.7s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.819 total time=   0.5s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.801 total time=   0.3s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.753 total time=   3.6s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.801 total time=   0.4s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.747 total time=   1.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.761 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.758 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.771 total time=   2.1s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.8s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.756 total time=   1.7s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.800 total time=   0.7s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.765 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.741 total time=   1.3s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.713 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.763 total time=   2.0s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.781 total time=   0.6s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.699 total time=   3.2s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.704 total time=   6.0s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.785 total time=   0.4s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.635 total time=   0.5s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.758 total time=   4.1s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   1.0s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.723 total time=   0.3s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.783 total time=   0.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.791 total time=   0.3s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.652 total time=   0.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.765 total time=   3.1s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   1.0s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.725 total time=   1.8s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.792 total time=   1.1s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.803 total time=   0.8s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   0.9s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.684 total time=   1.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   2.9s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.722 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.710 total time=   3.0s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.808 total time=   0.4s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.780 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.734 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.693 total time=   1.3s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.816 total time=   1.8s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.785 total time=   1.3s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.705 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.706 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.780 total time=   2.0s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.752 total time=   1.2s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.791 total time=   0.5s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.493 total time=   0.5s
# [CV 1/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.728 total time=   7.5s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.716 total time=   2.9s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.737 total time=   3.7s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.683 total time=   1.7s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.781 total time=   1.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.804 total time=   1.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.735 total time=   0.7s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.780 total time=   1.0s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.732 total time=   1.7s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.767 total time=   2.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.747 total time=   1.2s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.733 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.714 total time=   0.4s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.774 total time=   3.0s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.750 total time=   0.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.681 total time=   2.8s
# ...
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.694 total time=   8.5s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.758 total time=   0.3s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.753 total time=   0.3s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.713 total time=   5.6s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.783 total time=   0.5s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.745 total time=   1.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.738 total time=   0.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.678 total time=   0.5s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.763 total time=   4.0s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.741 total time=   0.3s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.696 total time=   1.8s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.792 total time=   1.2s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.803 total time=   0.8s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.768 total time=   0.9s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.715 total time=   1.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   2.9s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.780 total time=   0.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.722 total time=   0.4s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.710 total time=   3.0s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.808 total time=   0.4s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.780 total time=   0.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.734 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.685 total time=   1.1s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.764 total time=   1.6s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.8s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.717 total time=   2.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.6s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.734 total time=   1.2s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.747 total time=   0.4s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.493 total time=   0.5s
# [CV 1/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.728 total time=   6.9s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.716 total time=   2.9s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.765 total time=   3.4s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 2/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.705 total time=   1.6s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.745 total time=   3.7s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.785 total time=   0.3s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.716 total time=   3.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.6s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.739 total time=   0.3s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.699 total time=   3.5s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.785 total time=   0.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   0.8s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.681 total time=   2.8s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.763 total time=   0.6s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.741 total time=   0.4s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.754 total time=   2.1s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.782 total time=   0.5s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.765 total time=   0.4s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.729 total time=   0.8s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.737 total time=   2.5s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.738 total time=   0.7s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.782 total time=   0.9s
# [CV 5/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.713 total time=   8.4s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.775 total time=   0.3s
# [CV 3/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.740 total time=   0.3s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.753 total time=   5.5s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.717 total time=   0.6s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.723 total time=   1.2s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.767 total time=   0.4s
# [CV 4/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.652 total time=   0.5s
# [CV 1/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.763 total time=   3.9s
# [CV 2/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.796 total time=   0.3s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.740 total time=   0.4s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.703 total time=   3.5s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.790 total time=   0.5s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.729 total time=   0.3s
# [CV 1/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.697 total time=   1.3s
# [CV 5/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.764 total time=   2.8s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.780 total time=   0.8s
# [CV 1/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.684 total time=   2.8s
# [CV 4/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=None, scaler=StandardScaler();, score=0.723 total time=   0.6s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.731 total time=   1.1s
# [CV 2/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.752 total time=   0.3s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.796 total time=   0.3s
# [CV 5/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.769 total time=   2.0s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.741 total time=   0.4s
# [CV 2/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.726 total time=   1.1s
# [CV 4/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.780 total time=   1.9s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.797 total time=   1.1s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.779 total time=   0.5s
# [CV 3/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.480 total time=   0.5s
# [CV 4/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.739 total time=   4.2s
# [CV 2/5] END SVM__C=1, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.674 total time=   0.6s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.763 total time=   1.6s
# [CV 2/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.792 total time=   0.3s
# [CV 1/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.775 total time=   0.3s
# [CV 4/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.750 total time=   3.1s
# [CV 5/5] END SVM__C=1, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.767 total time=   3.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=linear, ros=None, scaler=MinMaxScaler();, score=0.745 total time=   0.3s
# [CV 3/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.727 total time=   4.4s
# [CV 5/5] END SVM__C=5, SVM__gamma=auto, SVM__kernel=rbf, ros=None, scaler=MinMaxScaler();, score=0.751 total time=   0.4s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.768 total time=   0.3s
# [CV 4/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=linear, ros=None, scaler=StandardScaler();, score=0.764 total time=   0.3s
# [CV 1/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.733 total time=   1.7s
# [CV 3/5] END SVM__C=5, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.795 total time=   2.2s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.801 total time=   1.1s
# [CV 2/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.762 total time=   0.3s
# [CV 3/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.722 total time=   0.4s
# [CV 4/5] END SVM__C=10, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.753 total time=   2.7s
# [CV 2/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.796 total time=   0.8s
# [CV 3/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=sigmoid, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.677 total time=   1.2s
# [CV 5/5] END SVM__C=10, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.748 total time=   2.3s
# [CV 4/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.731 total time=   1.1s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.715 total time=   0.3s
# [CV 3/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=sigmoid, ros=None, scaler=MinMaxScaler();, score=0.796 total time=   0.4s
# [CV 1/5] END SVM__C=50, SVM__gamma=auto, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.802 total time=   1.8s
# [CV 3/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=linear, ros=RandomOverSampler(random_state=42), scaler=MinMaxScaler();, score=0.739 total time=   1.4s
# [CV 5/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=sigmoid, ros=None, scaler=StandardScaler();, score=0.754 total time=   0.3s
# [CV 1/5] END SVM__C=50, SVM__gamma=scale, SVM__kernel=rbf, ros=RandomOverSampler(random_state=42), scaler=StandardScaler();, score=0.792 total time=   2.3s
